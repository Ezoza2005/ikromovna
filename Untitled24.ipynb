# %% [markdown]
# <a href="https://colab.research.google.com/github/Ezoza2005/ikromovna/blob/main/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from pandas import Series

# %%
df=pd.read_csv('uz.csv')
df
# Out:
#                city      lat      lng     country iso2        admin_name  \
# 0          Tashkent  41.3111  69.2797  Uzbekistan   UZ          Toshkent
# 1          Namangan  41.0011  71.6683  Uzbekistan   UZ          Namangan
# 2           Andijon  40.7833  72.3333  Uzbekistan   UZ           Andijon
# 3         Samarkand  39.6547  66.9758  Uzbekistan   UZ         Samarqand
# 4             Nukus  42.4667  59.6000  Uzbekistan   UZ  Qoraqalpog‘iston
# 5          Farg‘ona  40.3864  71.7864  Uzbekistan   UZ          Farg‘ona
# 6           Bukhara  39.7667  64.4231  Uzbekistan   UZ            Buxoro
# 7            Qarshi  38.8667  65.8000  Uzbekistan   UZ       Qashqadaryo
# 8            Qo‘qon  40.5286  70.9425  Uzbekistan   UZ          Farg‘ona
# 9         Marg‘ilon  40.4711  71.7247  Uzbekistan   UZ          Farg‘ona
# 10           Jizzax  40.1158  67.8422  Uzbekistan   UZ            Jizzax
# 11         Chirchiq  41.4667  69.5833  Uzbekistan   UZ          Toshkent
# ...

# %%
df.head(1)
# Out:
#        city      lat      lng     country iso2 admin_name  capital  \
# 0  Tashkent  41.3111  69.2797  Uzbekistan   UZ   Toshkent  primary
#
#    population  population_proper
# 0   2956384.0          2956384.0

# %%
df.shape
# Out:
# (52, 9)

# %%
df.tail(1)
# Out:
#            city      lat      lng     country iso2 admin_name capital  \
# 51  Oxunboboyev  40.7198  72.6428  Uzbekistan   UZ    Andijon   minor
#
#     population  population_proper
# 51         NaN                NaN

# %%
Obyekt=Series(['1899000','1384700','2597000','910500','1200000','1862000','767500','2029000','1200000','2322000','648100','1676000','4450000'],
                index=['Andijon','Buxoro','Fargona','Jizzax','Xorazm','Namangan','Navoiy','Qashqadaryo','Qoraqalpogiston respublisasi','Samarqand','Sirdaryo','Surxondaryo','Toshkent'])

# %%
print(Obyekt)
# Out:
# Andijon                         1899000
# Buxoro                          1384700
# Fargona                         2597000
# Jizzax                           910500
# Xorazm                          1200000
# Namangan                        1862000
# Navoiy                           767500
# Qashqadaryo                     2029000
# Qoraqalpogiston respublisasi    1200000
# Samarqand                       2322000
# Sirdaryo                         648100
# Surxondaryo                     1676000
# Toshkent                        4450000
# dtype: object

# %%
Obyekt[Obyekt>1000000]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-6fbe4cff3a67> in <cell line: 1>()
# ----> 1 Obyekt[Obyekt>1000000]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      79         other = item_from_zerodim(other)
#      80
# ---> 81         return method(self, other)
#      82
#      83     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __gt__(self, other)
#      54     @unpack_zerodim_and_defer("__gt__")
#      55     def __gt__(self, other):
# ---> 56         return self._cmp_method(other, operator.gt)
#      57
#      58     @unpack_zerodim_and_defer("__ge__")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    6094
#    6095         with np.errstate(all="ignore"):
# ...

# %%
Obyekt[Obyekt<1000000]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-da25b8fb8ac8> in <cell line: 1>()
# ----> 1 Obyekt[Obyekt<1000000]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      79         other = item_from_zerodim(other)
#      80
# ---> 81         return method(self, other)
#      82
#      83     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __lt__(self, other)
#      46     @unpack_zerodim_and_defer("__lt__")
#      47     def __lt__(self, other):
# ---> 48         return self._cmp_method(other, operator.lt)
#      49
#      50     @unpack_zerodim_and_defer("__le__")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    6094
#    6095         with np.errstate(all="ignore"):
# ...
